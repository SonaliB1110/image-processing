# %%
#resize
from PIL import Image
filepath='img1.jpg'
img=Image.open(filepath)
new_image=img.resize((300,200))
new_image
# Out:
# <PIL.Image.Image image mode=RGB size=300x200 at 0x27DD97E5C40>

# %%
#rotate
from PIL import Image
im=Image.open('img1.jpg')
angle=45
out=im.rotate(angle,expand=True)
out.save('rotate_output.jpg')
out
# Out:
# <PIL.Image.Image image mode=RGB size=532x532 at 0x27DD7DFC7C0>

# %%
#quantization
import cv2
from PIL import Image
image=Image.open('img1.jpg')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x250 at 0x27DD95E0C10>

# %%
img=image.quantize(19)
img
# Out:
# <PIL.Image.Image image mode=P size=500x250 at 0x27DD97E5280>
