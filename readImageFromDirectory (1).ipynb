# %%
# import the modules
import os
from os import listdir

# get the path/directory
folder_dir = "D:\Imge"
for images in os.listdir(folder_dir):

# check if the image ends with png
     if (images.endswith(".png")):
        print(images)
# Out:
# balloon.png
# bird1.png
# loc.png
# O.png
# OO.png
# ooo.png
# sman.png
# trishul.png
# wings.png
# xx.png
# ytube.png

# %%
# import the modules
import os
from os import listdir
 
# get the path or directory
folder_dir = "D:\images"
for images in os.listdir(folder_dir):
 
    # check if the image ends with png or jpg or jpeg
    if (images.endswith(".png") or images.endswith(".jpg")\
        or images.endswith(".jpeg")or images.endswith(".pdf")):
        # display
        print(images)
# Out:
# android.png
# Ari.jpg
# Arithmetic.jpg
# beatiful-eye-27391.jpg
# bg.jpg
# bgc.jpg
# bgnd.jpg
# bgs.jpg
# brd.png
# but.png
# cat_damaged.png
# cat_mask.png
# croppedBeach1.jpg
# damaged.jpg
# damaged_astronaut.png
# dice.png
# Dice2.png
# dice4.jpg
# dice5.jpg
# dice6.jpg
# dice7.png
# dimg.jpg
# dog.jpg
# dot.jpg
# download.png
# einstin.png
# F1.png
# F1_FLOWER.png
# f2.jpg
# face.jpg
# face0.jpg
# face1.jpg
# face2.jpg
# face5.jpg
# face6.jpg
# face7.jpg
# face8.jpg
# flower.jpg
# girl.jpg
# histo.png
# i1.png
# i10.png
# i2.png
# i3.png
# i4.png
# i5.png
# i6.png
# i7.png
# i8.png
# i9.png
# im1.png
# img1.jpg
# img2.jpg
# img3.jpg
# img4.jpg
# img5.jpg
# king.jpg
# krishna.jpg
# logo.png
# logo1.png
# logo2.png
# me.png
# mee.png
# namemyself.png
# negation.jpg
# noise.png
# pinkrose.jpg
# prof12.png
# profile.png
# profile1.png
# profile2.png
# RAKSHA FEES.pdf
# rose.jpg
# rosew.jpg
# s.jpg
# Sandipan Dey - Hands-On Image Processing with Python-Packt Publishing (2018).pdf
# sci.jpg
# star.jpg
# train.jpg
# Ut.jpg
# v.jpg
# waterdrop.jpg
# watermark.jpg
