# %%
from PIL import Image
import os
os.getcwd()
# Out:
# 'C:\\Users\\User\\Image Processing'

# %%
image1 = Image.open("img1.jpg")

image1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x250 at 0x1A60EEB0100>

# %%
image1.show()

# %%
#Changing File type (Extension)
image1.save("img3.png")

# %%
# lists all the files and folders in the current working directory
os.listdir()
# Out:
# ['.idea',
#  '.ipynb_checkpoints',
#  '10-01-22(folder image name).ipynb',
#  '12-01-23(lab exercise).ipynb',
#  'Ari.jpg',
#  'arithmaticOperation.ipynb',
#  'Arithmetic.jpg',
#  'Automate the image.ipynb',
#  'backgroundImage.ipynb',
#  'bg.jpg',
#  'bgc.jpg',
#  'bgnd.jpg',
#  'bgs.jpg',
#  'binary image.ipynb',
#  'Bitwise Operator.ipynb',
#  'blinding.ipynb',
#  'boat.jfif',
#  'but.png',
#  'canvas program.ipynb',
#  'cat_damaged.png',
#  'cat_inpainted.png',
#  'cat_mask.png',
#  'contour.ipynb',
#  'contours(horse).ipynb',
#  'crop.png',
#  'damage.jpg',
#  'damaged.jpg',
#  'damage_inpaint.png',
#  'dice contour.ipynb',
#  'dice.png',
#  'dice1.png',
#  'Dice2.png',
#  'dice3.jfif',
#  'dice4.jpg',
#  'dice5.jpg',
#  'dice6.jpg',
#  'dice7.png',
#  'dice8.jpg',
#  'dimg.jpg',
#  'dog.jpg',
#  'dot.jpg',
#  'einstin.png',
#  'F1.png',
#  'f2.jpg',
#  'face.jpg',
#  'face1.jpg',
#  'Filtering.ipynb',
#  'flower.jpg',
#  'folder image with negative.ipynb',
#  'histogram.ipynb',
#  'image manipulation(lab excerise).ipynb',
#  'image restoration(sample).ipynb',
#  'Image restoration.py',
#  'image.png',
#  'Image_mask.jpg',
#  'img1.jpg',
#  'img2.jpg',
#  'img3.jpg',
#  'img3.png',
#  'img4.jpg',
#  'img5.jpg',
#  'impnt.png',
#  'inpaint.png',
#  'inpaintdd.png',
#  'inpainted.png',
#  'intensity Transformation.ipynb',
#  'interpolation.ipynb',
#  'inverting.ipynb',
#  'king.jpg',
#  'kk.png',
#  'krishna.jpg',
#  'logo.png',
#  'logo2.webp',
#  'mask.jpg',
#  'maskk.jpg',
#  'masks.jpg',
#  'me.png',
#  'mee.png',
#  'minpaint.png',
#  'montage program.ipynb',
#  'montage without skimage.ipynb',
#  'my.png',
#  'nature.jpg',
#  'NewExtnsn',
#  'pil_grayscale.png',
#  'pinkrose.jpg',
#  'read various library.ipynb',
#  'remove logo.ipynb',
#  'resize',
#  'resize rotate quantize .ipynb',
#  'restoration.ipynb',
#  'RGB channels.ipynb',
#  'rose.jpg',
#  'rosew.jpg',
#  'rotate_output.jpg',
#  's.jpg',
#  'sample library.ipynb',
#  'sample.ipynb',
#  'sample2.ipynb',
#  'sci.jpg',
#  'skimage_gray.png',
#  'star.jpg',
#  'taj.jfif',
#  'text on image.ipynb',
#  'text remove.ipynb',
#  'text_removed_image.jpg',
#  'train.jpg',
#  'Untitled.ipynb',
#  'Ut.jpg',
#  'v.jpg',
#  'watermark.jpg']

# %%
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        print(fn, "&", fext)
# Out:
# Ari & .jpg
# Arithmetic & .jpg
# bg & .jpg
# bgc & .jpg
# bgnd & .jpg
# bgs & .jpg
# damage & .jpg
# damaged & .jpg
# dice4 & .jpg
# dice5 & .jpg
# dice6 & .jpg
# dice8 & .jpg
# dimg & .jpg
# dog & .jpg
# dot & .jpg
# f2 & .jpg
# face & .jpg
# face1 & .jpg
# flower & .jpg
# Image_mask & .jpg
# img1 & .jpg
# img2 & .jpg
# img3 & .jpg
# img4 & .jpg
# img5 & .jpg
# king & .jpg
# krishna & .jpg
# mask & .jpg
# maskk & .jpg
# masks & .jpg
# nature & .jpg
# pinkrose & .jpg
# rose & .jpg
# rosew & .jpg
# rotate_output & .jpg
# s & .jpg
# sci & .jpg
# star & .jpg
# text_removed_image & .jpg
# train & .jpg
# Ut & .jpg
# v & .jpg
# watermark & .jpg

# %%
#Looping over the image files
for f in os.listdir("."):
    if f.endswith(".jpg"):
        print(f)
# Out:
# Ari.jpg
# Arithmetic.jpg
# bg.jpg
# bgc.jpg
# bgnd.jpg
# bgs.jpg
# damage.jpg
# damaged.jpg
# dice4.jpg
# dice5.jpg
# dice6.jpg
# dice8.jpg
# dimg.jpg
# dog.jpg
# dot.jpg
# f2.jpg
# face.jpg
# face1.jpg
# flower.jpg
# Image_mask.jpg
# img1.jpg
# img2.jpg
# img3.jpg
# img4.jpg
# img5.jpg
# king.jpg
# krishna.jpg
# mask.jpg
# maskk.jpg
# masks.jpg
# nature.jpg
# pinkrose.jpg
# rose.jpg
# rosew.jpg
# rotate_output.jpg
# s.jpg
# sci.jpg
# star.jpg
# text_removed_image.jpg
# train.jpg
# Ut.jpg
# v.jpg
# watermark.jpg

# %%
# Creating new Directory using OS library
os.mkdir('NewExtnsn')
# Note: If you already have a directory with this name, you will get error.
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        i.save("NewExtnsn/{}.pdf".format(fn))
print("directory created")
        #look into NewExtnsn directory
# Out:
# directory created

# %%
# Creating new multiple Directories using OS library
os.makedirs('resize//small')
os.makedirs('resize//tiny')
# Note: If you already have a directory with this name, you will get error.
size_small = (600,600) # small images of 600 X 600 pixels
size_tiny = (200,200)  # tiny images of 200 X 200 pixels
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        i.thumbnail(size_small)
        i.save("resize/small/{}_small{}".format(fn, fext))
        i.thumbnail(size_tiny)
        i.save("resize/tiny/{}_tiny{}".format(fn, fext))
print("look into resize//small and resize//tiny directory")
# Out:
# look into resize//small and resize//tiny directory

# %%
#Converting to Black and White
image2 = Image.open("img1.jpg")
image2 = image2.convert(mode='L')
image2
# Out:
# <PIL.Image.Image image mode=L size=500x250 at 0x1A60EEBA8E0>

# %%
# Creating new Directory using OS library
os.mkdir('b&w')
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        im = i.convert(mode = 'L')
        im.save("b&w/{}_bw.{}".format(fn, fext))
print("look into b&w directory")
# Out:
# look into b&w directory

# %%
#Rotating the Images
#rotating the image to 55 Degree angle
image3 = Image.open("flower.jpg")
image3.rotate(55).save("img1.jpg")
Image3 = Image.open("flower.jpg")
Image3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x720 at 0x1A60F09D970>

# %%
# Creating new Directory using OS library
os.mkdir('rotate')
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        im = i.rotate(90)
        im.save("rotate/{}_rot.{}".format(fn, fext))
print("look into rotate directory")
# Out:
# look into rotate directory
