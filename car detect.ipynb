# %%
# Import libraries
from PIL import Image
import cv2
import numpy as np
import requests

# %%
image=Image.open("car4.jfif")
#image = Image.open(requests.get('https://a57.foxnews.com/media.foxbusiness.com/BrightCove/854081161001/201805/2879/931/524/854081161001_5782482890001_5782477388001-vs.jpg', stream=True).raw)
image = image.resize((450,250))
image_arr = np.array(image)
image
# Out:
# <PIL.Image.Image image mode=RGB size=450x250 at 0x2B0197E5F10>

# %%
grey = cv2.cvtColor(image_arr,cv2.COLOR_BGR2GRAY)
Image.fromarray(grey)
# Out:
# <PIL.Image.Image image mode=L size=450x250 at 0x2B019803A30>

# %%
blur = cv2.GaussianBlur(grey,(5,5),0)
Image.fromarray(blur)
# Out:
# <PIL.Image.Image image mode=L size=450x250 at 0x2B0198D1B20>

# %%
dilated = cv2.dilate(blur,np.ones((3,3)))
Image.fromarray(dilated)
# Out:
# <PIL.Image.Image image mode=L size=450x250 at 0x2B0198D1370>

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (2, 2))
closing = cv2.morphologyEx(dilated, cv2.MORPH_CLOSE, kernel) 
Image.fromarray(closing)
# Out:
# <PIL.Image.Image image mode=L size=450x250 at 0x2B0198D10A0>

# %%
car_cascade_src = 'carss.xml'
car_cascade = cv2.CascadeClassifier(car_cascade_src)
cars = car_cascade.detectMultiScale(closing, 1.1, 1)
cars
# Out:
# array([[214, 110,  92,  92]])

# %%
cnt = 0
for (x,y,w,h) in cars:
    cv2.rectangle(image_arr,(x,y),(x+w,y+h),(255,0,0),2)
    cnt += 1
print(cnt, " cars found")
Image.fromarray(image_arr)
# Out:
# 1  cars found
# <PIL.Image.Image image mode=RGB size=450x250 at 0x2B0197E5E20>
