# %%
from PIL import Image,ImageDraw,ImageFont
from PIL import ImageDraw
img = Image.open('king.jpg')
I1 = ImageDraw.Draw(img)
font = ImageFont.truetype("arial",50)
I1.text((90, 90),"GOOD MORNING", fill=(255, 0, 0),font=font)
img.show()
img.save("image.png")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=510x340 at 0x19BB13391F0>
